# %%
import pandas as pd
import numpy as np
import re


input_value = {'model_file': '%Input Folder%\\resident\\dc\\GAN\\N_HBSRO\\best_model.pt', 
    'parameter_file':'%Input Folder%\\resident\\dc\\GAN\\N_HBSRO\\model_setup.yaml', 
    'se_file': 'C:\\models\\Reno_TDM\\scenarios\\base_2022/output/sedata/scenario_se.bin', 
    'skim_file': 'C:\\models\\Reno_TDM\\scenarios\\base_2022\\output\\skims\\roadway/avg_skim_AM_N_HB_sov.mtx', 
    'output_folder': None,
    'Input Folder': 'C:\\models\\Reno_TDM\\scenarios\\base_2022\\input'}

for key, value in input_value.items():
    if not value is None:
        print(f'{key}: {value}')
        value = value.lower().replace("%input folder%", input_value['Input Folder'])
        print(f'{key}: {value}')
# Out:
# model_file: %Input Folder%\resident\dc\GAN\N_HBSRO\best_model.pt
# model_file: C:\models\Reno_TDM\scenarios\base_2022\input\resident\dc\gan\n_hbsro\best_model.pt
# parameter_file: %Input Folder%\resident\dc\GAN\N_HBSRO\model_setup.yaml
# parameter_file: C:\models\Reno_TDM\scenarios\base_2022\input\resident\dc\gan\n_hbsro\model_setup.yaml
# se_file: C:\models\Reno_TDM\scenarios\base_2022/output/sedata/scenario_se.bin
# se_file: c:\models\reno_tdm\scenarios\base_2022/output/sedata/scenario_se.bin
# skim_file: C:\models\Reno_TDM\scenarios\base_2022\output\skims\roadway/avg_skim_AM_N_HB_sov.mtx
# skim_file: c:\models\reno_tdm\scenarios\base_2022\output\skims\roadway/avg_skim_am_n_hb_sov.mtx
# Input Folder: C:\models\Reno_TDM\scenarios\base_2022\input
# Input Folder: c:\models\reno_tdm\scenarios\base_2022\input
